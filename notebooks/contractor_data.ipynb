# %%
import glob
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# %%
url = "https://www.nhsbsa.nhs.uk/prescription-data/dispensing-data/dispensing-contractors-data"
base_url = "https://www.nhsbsa.nhs.uk"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

csv_links = []

for link in soup.find_all('a', href=True):
    href = link['href']
    if href.endswith('.csv') and 'Dispensing%20Data' in href:
        full_url = base_url + href
        csv_links.append(full_url)

def extract_yyyymm_from_url(url):
    parts = url.split('%20')
    month_mapping = {
        'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04', 'May': '05', 'Jun': '06',
        'Jul': '07', 'Aug': '08', 'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dec': '12',
        'January': '01', 'February': '02', 'March': '03', 'April': '04', 'May': '05', 'June': '06',
        'July': '07', 'August': '08', 'September': '09', 'October': '10', 'November': '11', 'December': '12'
    }

    # Extract the month abbreviation and the year part from the URL
    for i, part in enumerate(parts):
        if part in month_mapping:
            month_str = month_mapping[part]
            year_str = parts[i + 1][:2]
            break
    else:
        return None

    # Convert 2-digit year to 4-digit year
    year_number_str = f'20{year_str}'

    return year_number_str + month_str

link_list=[]

for link in csv_links:
    yyyymm = extract_yyyymm_from_url(link)
    #print(f"Full URL: {link}, Extracted YYYYMM: {yyyymm}")
    link_list.append({'month': yyyymm, 'url': link})

df = pd.DataFrame(link_list)

# Convert the 'month' column to datetime
df['month'] = pd.to_datetime(df['month'], format='%Y%m')

# Filter the DataFrame to only include months on or after February 2024
filtered_df = df[df['month'] >= '2024-02-01']

# List to hold the resulting dataframes
df_list = []

# Iterate through the filtered_df
for index, row in filtered_df.iterrows():
    #print(f"Month: {row['month']}, URL: {row['url']}")
    df_fetched = pd.read_csv(row['url'])
    df_fetched['month'] = row['month']
    df_list.append(df_fetched)

# Combine all dataframes in df_list into a single dataframe
combined_df = pd.concat(df_list, ignore_index=True)

# Display the combined dataframe
#combined_df.head(5)

combined_df.to_csv("../data/contractor_data.csv", index=False)

# %%
filtered_df
# Out:
#        month                                                url
# 1 2024-02-01  https://www.nhsbsa.nhs.uk/sites/default/files/...
# 2 2024-03-01  https://www.nhsbsa.nhs.uk/sites/default/files/...
# 3 2024-04-01  https://www.nhsbsa.nhs.uk/sites/default/files/...
# 4 2024-05-01  https://www.nhsbsa.nhs.uk/sites/default/files/...

# %%
combined_df.dtypes
# Out:
# ICBCode                                                                                                  object
# ICB                                                                                                      object
# Contractor Type                                                                                          object
# ContractorCode                                                                                           object
# ContractorName                                                                                           object
# Address                                                                                                  object
#                                                                                                          object
#                                                                                                          object
#                                                                                                          object
# Postcode                                                                                                 object
# NumberofForms                                                                                             int64
# NumberofItems                                                                                             int64
# TotalnumberofPrescriptions(ProfessionalFees)                                                              int64
# NumberofPrescriptions(ProfessionalFees)(Standarddiscountrate)                                             int64
# NumberofPrescriptions(ProfessionalFees)(Zerodiscountrate)                                                 int64
# NumberofformsforElectronicPrescriptionService(EPS)                                                        int64
# NumberofItemsprocessedviaElectronicPrescriptionService(EPS)                                               int64
# NumberofMedicineUseReviews(MURs)declared                                                                  int64
# NumberofNewMedicineService(NMS)interventionsdeclared                                                      int64
# NumberofApplianceUseReviews(AURs)conductedinusershomes                                                    int64
# NumberofApplianceUseReviews(AURs)conductedatpremises                                                      int64
# NumberofStomaCustomisationFees                                                                            int64
# NumberofCOVID19HomeDeliveryFees                                                                           int64
# NumberofCommunityPharmacistConsultationService(CPCS)Fees                                                  int64
# NumberofCommunityPharmacyHepatitisCAntibodyTestingServiceFees                                             int64
# NumberofCommunityPharmacyCompletedTransactionsforCovid-19LateralFlowDeviceDistributionService             int64
# NumberofCommunityPharmacyClinicBloodPressurechecks                                                        int64
# NumberofCommunityPharmacyAmbulatoryBloodPressureMonitoring(ABPM)                                          int64
# NumberofCommunityPharmacySmokingCessationConsultations                                                    int64
# NumberofCompleteDischargeMedicinesServices                                                                int64
# NumberofIncompleteDischargeMedicinesServices                                                              int64
# NumberofSeriousShortageProtocol(SSP)Fees                                                                  int64
# NumberofInfluenzaAdministeredFees                                                                         int64
# NumberofCommunityPharmacyContraceptiveOngoingConsultations                                                int64
# NumberofCommunityPharmacyContraceptiveInitiationConsultations                                             int64
# NumberofLateralFlowDevice(LFD)TestSupplyServiceFees                                                       int64
# NumberofPharmacyFirstClinicalPathwaysConsultations-AcuteOtitisMedia                                       int64
# NumberofPharmacyFirstClinicalPathwaysConsultations -AcuteSoreThroat                                       int64
# NumberofPharmacyFirstClinicalPathwaysConsultations-Impetigo                                               int64
# NumberofPharmacyFirstClinicalPathwaysConsultations-InfectedInsectBites                                    int64
# NumberofPharmacyFirstClinicalPathwaysConsultations-Shingles                                               int64
# NumberofPharmacyFirstClinicalPathwaysConsultations-Sinusitis                                              int64
# NumberofPharmacyFirstClinicalPathwaysConsultations-UncomplicatedUTI                                       int64
# NumberofPharmacyFirstUrgentMedicineSupplyConsultations                                                    int64
# NumberofPharmacyFirstMinorIllnessReferralConsultations                                                    int64
# month                                                                                            datetime64[ns]
# dtype: object

# %%
# Keep only the specified columns
columns_to_keep = [
    'ICBCode', 'ICB', 'TotalnumberofPrescriptions(ProfessionalFees)', 'NumberofMedicineUseReviews(MURs)declared',
    'NumberofNewMedicineService(NMS)interventionsdeclared', 'NumberofCommunityPharmacistConsultationService(CPCS)Fees',
    'NumberofCommunityPharmacyClinicBloodPressurechecks', 'NumberofCommunityPharmacyAmbulatoryBloodPressureMonitoring(ABPM)',
    'NumberofCommunityPharmacyContraceptiveOngoingConsultations', 'NumberofCommunityPharmacyContraceptiveInitiationConsultations',
    'NumberofPharmacyFirstClinicalPathwaysConsultations-AcuteOtitisMedia', 'NumberofPharmacyFirstClinicalPathwaysConsultations -AcuteSoreThroat',
    'NumberofPharmacyFirstClinicalPathwaysConsultations-Impetigo', 'NumberofPharmacyFirstClinicalPathwaysConsultations-InfectedInsectBites',
    'NumberofPharmacyFirstClinicalPathwaysConsultations-Shingles', 'NumberofPharmacyFirstClinicalPathwaysConsultations-Sinusitis',
    'NumberofPharmacyFirstClinicalPathwaysConsultations-UncomplicatedUTI', 'NumberofPharmacyFirstUrgentMedicineSupplyConsultations',
    'NumberofPharmacyFirstMinorIllnessReferralConsultations', 'month'
]

combined_df = combined_df[columns_to_keep]

# Group by 'ICBCode', 'ICB', and 'month', then sum the other columns
grouped_df = combined_df.groupby(['ICBCode', 'ICB', 'month']).sum().reset_index()

# Display the grouped dataframe
print(grouped_df)
# Out:
#     ICBCode                               ICB      month  \
# 0       QE1  LANCASHIRE AND SOUTH CUMBRIA ICB 2024-02-01
# 1       QE1  LANCASHIRE AND SOUTH CUMBRIA ICB 2024-03-01
# 2       QE1  LANCASHIRE AND SOUTH CUMBRIA ICB 2024-04-01
# 3       QE1  LANCASHIRE AND SOUTH CUMBRIA ICB 2024-05-01
# 4       QF7               SOUTH YORKSHIRE ICB 2024-02-01
# ..      ...                               ...        ...
# 163     QXU             SURREY HEARTLANDS ICB 2024-05-01
# 164     QYG       CHESHIRE AND MERSEYSIDE ICB 2024-02-01
# 165     QYG       CHESHIRE AND MERSEYSIDE ICB 2024-03-01
# 166     QYG       CHESHIRE AND MERSEYSIDE ICB 2024-04-01
# 167     QYG       CHESHIRE AND MERSEYSIDE ICB 2024-05-01
#
#      TotalnumberofPrescriptions(ProfessionalFees)  \
# 0                                         3359960
# 1                                         3414087
# 2                                         3530667
# 3                                         3602997
# 4                                         2930440
# ..                                            ...
# 163                                       1153437
# 164                                       5110169
# 165                                       5161231
# 166                                       5373644
# 167                                       5461137
#
#      NumberofMedicineUseReviews(MURs)declared  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ..                                        ...
# 163                                         0
# 164                                         0
# 165                                         0
# 166                                         0
# 167                                         0
#
#      NumberofNewMedicineService(NMS)interventionsdeclared  \
# 0                                                14812
# 1                                                14362
# 2                                                14652
# 3                                                15913
# 4                                                12810
# ..                                                 ...
# 163                                               5908
# 164                                              20548
# 165                                              20071
# 166                                              21445
# 167                                              22596
#
#      NumberofCommunityPharmacistConsultationService(CPCS)Fees  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 163                                                  0
# 164                                                  0
# 165                                                  0
# 166                                                  0
# 167                                                  0
#
#      NumberofCommunityPharmacyClinicBloodPressurechecks  \
# 0                                                 5806
# 1                                                 5836
# 2                                                 7319
# 3                                                 7875
# 4                                                 5294
# ..                                                 ...
# 163                                               2807
# 164                                               8914
# 165                                               9441
# 166                                              10898
# 167                                              12874
#
#      NumberofCommunityPharmacyAmbulatoryBloodPressureMonitoring(ABPM)  \
# 0                                                 1102
# 1                                                 1263
# 2                                                 1381
# 3                                                 1338
# 4                                                  497
# ..                                                 ...
# 163                                                 82
# 164                                               1149
# 165                                               1177
# 166                                               1383
# 167                                               1209
#
#      NumberofCommunityPharmacyContraceptiveOngoingConsultations  \
# 0                                                  170
# 1                                                  196
# 2                                                  298
# 3                                                  371
# 4                                                  404
# ..                                                 ...
# 163                                                218
# 164                                                486
# 165                                                550
# 166                                                745
# 167                                                854
#
#      NumberofCommunityPharmacyContraceptiveInitiationConsultations  \
# 0                                                   41
# 1                                                   45
# 2                                                   60
# 3                                                   97
# 4                                                   48
# ..                                                 ...
# 163                                                 39
# 164                                                126
# 165                                                126
# 166                                                146
# 167                                                199
#
#      NumberofPharmacyFirstClinicalPathwaysConsultations-AcuteOtitisMedia  \
# 0                                                  966
# 1                                                  962
# 2                                                  822
# 3                                                  787
# 4                                                  380
# ..                                                 ...
# 163                                                296
# 164                                               1212
# 165                                               1205
# 166                                                912
# 167                                                899
#
#      NumberofPharmacyFirstClinicalPathwaysConsultations -AcuteSoreThroat  \
# 0                                                 2085
# 1                                                 2575
# 2                                                 2468
# 3                                                 2363
# 4                                                  878
# ..                                                 ...
# 163                                                730
# 164                                               2453
# 165                                               2814
# 166                                               2842
# 167                                               2680
#
#      NumberofPharmacyFirstClinicalPathwaysConsultations-Impetigo  \
# 0                                                  394
# 1                                                  334
# 2                                                  354
# 3                                                  290
# 4                                                  200
# ..                                                 ...
# 163                                                 95
# 164                                                461
# 165                                                398
# 166                                                394
# 167                                                375
#
#      NumberofPharmacyFirstClinicalPathwaysConsultations-InfectedInsectBites  \
# 0                                                  174
# 1                                                  198
# 2                                                  235
# 3                                                  567
# 4                                                   77
# ..                                                 ...
# 163                                                278
# 164                                                177
# 165                                                216
# 166                                                272
# 167                                               1041
#
#      NumberofPharmacyFirstClinicalPathwaysConsultations-Shingles  \
# 0                                                  171
# 1                                                  192
# 2                                                  200
# 3                                                  185
# 4                                                  118
# ..                                                 ...
# 163                                                 63
# 164                                                269
# 165                                                250
# 166                                                252
# 167                                                292
#
#      NumberofPharmacyFirstClinicalPathwaysConsultations-Sinusitis  \
# 0                                                  955
# 1                                                  900
# 2                                                  825
# 3                                                  688
# 4                                                  423
# ..                                                 ...
# 163                                                265
# 164                                               1159
# 165                                                995
# 166                                                956
# 167                                                902
#
#      NumberofPharmacyFirstClinicalPathwaysConsultations-UncomplicatedUTI  \
# 0                                                 1254
# 1                                                 1219
# 2                                                 1461
# 3                                                 1681
# 4                                                  631
# ..                                                 ...
# 163                                                560
# 164                                               2275
# 165                                               2206
# 166                                               2761
# 167                                               2796
#
#      NumberofPharmacyFirstUrgentMedicineSupplyConsultations  \
# 0                                                 3372
# 1                                                 4163
# 2                                                 3693
# 3                                                 4447
# 4                                                 1606
# ..                                                 ...
# 163                                               1676
# 164                                               4670
# 165                                               5991
# 166                                               5551
# 167                                               6800
#
#      NumberofPharmacyFirstMinorIllnessReferralConsultations
# 0                                                 6096
# 1                                                 5846
# 2                                                 4972
# 3                                                 4793
# 4                                                 2472
# ..                                                 ...
# 163                                               1362
# 164                                               5329
# 165                                               4842
# 166                                               3895
# 167                                               3868
#
# [168 rows x 20 columns]
